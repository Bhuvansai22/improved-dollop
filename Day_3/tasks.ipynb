# %% [markdown]
# ### Task 1.1
#
# """
# use BERT and GPT-2 tokenizers to tokenize `Python is a great programming language` and compare the results. This will help you understand how different tokenization strategies work and how they affect the input representation for language models.
# """

# %% [markdown]
# ### Task 1.2
# """
# print all the special tokens used by the BERT and GPT-2 tokenizers. This will give you insight into how these tokenizers handle special cases, such as padding, unknown tokens, and sentence separation, which are crucial for understanding how they process input text.
# """

# %% [markdown]
# ### Task 1.3
# """
# print the vocabulary size of both the BERT and GPT-2 tokenizers. This will help you understand the capacity of each tokenizer to represent different words and subwords, which can impact the performance of language models that use these tokenizers.
# """
