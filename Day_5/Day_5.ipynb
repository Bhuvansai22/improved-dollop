# %% [markdown]
# # Day 5: Retrieval-Augmented Generation (RAG)
#
# - RAG pipeline using LangChain (open-source)
# - Document loading, chunking, retrieval
# - Build a mini RAG system

# %%
# Introduction to RAG
def what_is_rag():
    return ("RAG (Retrieval-Augmented Generation) augments LLMs with external knowledge by retrieving relevant documents and using them as context for generation.")
print(what_is_rag())

# %%
# Basic RAG pipeline using LangChain
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains import RetrievalQA
from langchain.llms import OpenAI

documents = ["LangChain is a framework for developing applications powered by language models.",
             "RAG combines retrieval and generation for better answers."]
splitter = CharacterTextSplitter(chunk_size=100, chunk_overlap=10)
chunks = splitter.create_documents(documents)
embeddings = OpenAIEmbeddings()
vectorstore = FAISS.from_documents(chunks, embeddings)
retriever = vectorstore.as_retriever()
qa = RetrievalQA.from_chain_type(llm=OpenAI(), retriever=retriever)
query = 'What is LangChain?'
result = qa.run(query)
print('Q:', query)
print('A:', result)

# %%
# Document loading and chunking
from langchain.text_splitter import CharacterTextSplitter
documents = ["This is a sample document for RAG demonstration. It will be split into chunks."]
splitter = CharacterTextSplitter(chunk_size=50, chunk_overlap=10)
chunks = splitter.create_documents(documents)
for i, chunk in enumerate(chunks):
    print(f'Chunk {i+1}: {chunk.page_content}')

# %%
# Retrieval example
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
documents = ["RAG uses retrieval to find relevant information.",
             "LangChain supports various retrievers."]
embeddings = OpenAIEmbeddings()
vectorstore = FAISS.from_texts(documents, embeddings)
retriever = vectorstore.as_retriever()
query = 'What does RAG use?'
results = retriever.get_relevant_documents(query)
for i, doc in enumerate(results):
    print(f'Result {i+1}: {doc.page_content}')

# %%
# Mini RAG system
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains import RetrievalQA
from langchain.llms import OpenAI
documents = ["LangChain enables RAG pipelines easily.",
    "Retrieval-Augmented Generation improves LLM answers.",
    "Chunking helps in efficient retrieval.",
    "FAISS is a fast vector store for similarity search."]
splitter = CharacterTextSplitter(chunk_size=60, chunk_overlap=10)
chunks = splitter.create_documents(documents)
embeddings = OpenAIEmbeddings()
vectorstore = FAISS.from_documents(chunks, embeddings)
retriever = vectorstore.as_retriever()
qa = RetrievalQA.from_chain_type(llm=OpenAI(), retriever=retriever)
query = 'How does RAG improve LLMs?'
result = qa.run(query)
print('Q:', query)
print('A:', result)
